# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Social_Network_Ads.csv")

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
dataset=dataset.drop("User ID",axis=1)

# %%
dataset
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0            1
# 1     35            20000          0            1
# 2     26            43000          0            0
# 3     27            57000          0            0
# 4     19            76000          0            1
# ..   ...              ...        ...          ...
# 395   46            41000          1            0
# 396   51            23000          1            1
# 397   50            20000          1            0
# 398   36            33000          0            1
# 399   49            36000          1            0
#
# [400 rows x 4 columns]

# %%
dataset[["Purchased"]].value_counts()
# Out:
# Purchased
# 0            257
# 1            143
# Name: count, dtype: int64

# %%
dataset.columns
# Out:
# Index(['Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='object')

# %%
independent=dataset[['Age', 'EstimatedSalary', 'Gender_Male']]
dependent=dataset[['Purchased']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=1/3,random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
pram_grid={
    'n_neighbors':[5,10,15],
    'weights':['uniform', 'distance'],
    'algorithm':['auto', 'ball_tree', 'kd_tree', 'brute'],
    'leaf_size':[30,40,50],
    'p':[1,2]
}
grid= GridSearchCV(KNeighborsClassifier,pram_grid,refit=True, n_jobs=-1,verbose=3)
grid.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 11
#       3 pram_grid={
#       4     'n_neighbors':[5,10,15],
#       5     'weights':['uniform', 'distance'],
#    (...)
#       8     'p':[1,2]
#       9 }
#      10 grid= GridSearchCV(KNeighborsClassifier,pram_grid,refit=True, n_jobs=-1,verbose=3)
# ---> 11 grid.fit(x_train,y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:812, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     809 cv_orig = check_cv(self.cv, y, classifier=is_classifier(estimator))
#     810 n_splits = cv_orig.get_n_splits(X, y, groups)
# --> 812 base_estimator = clone(self.estimator)
#     814 parallel = Parallel(n_jobs=self.n_jobs, pre_dispatch=self.pre_dispatch)
#     816 fit_and_score_kwargs = dict(
#     817     scorer=scorers,
#     818     fit_params=fit_params,
#    (...)
#     824     verbose=self.verbose,
#     825 )
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:76, in clone(estimator, safe)
#      74 if hasattr(estimator, "__sklearn_clone__") and not inspect.isclass(estimator):
#      75     return estimator.__sklearn_clone__()
# ---> 76 return _clone_parametrized(estimator, safe=safe)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:91, in _clone_parametrized(estimator, safe)
#      89 else:
#      90     if isinstance(estimator, type):
# ---> 91         raise TypeError(
#      92             "Cannot clone object. "
#      93             + "You should provide an instance of "
#      94             + "scikit-learn estimator instead of a class."
#      95         )
#      96     else:
#      97         raise TypeError(
#      98             "Cannot clone object '%s' (type %s): "
#      99             "it does not seem to be a scikit-learn "
#     100             "estimator as it does not implement a "
#     101             "'get_params' method." % (repr(estimator), type(estimator))
#     102         )
#
# TypeError: Cannot clone object. You should provide an instance of scikit-learn estimator instead of a class.
